# %%
# C Language ALL QUESTIONS . Total 3 DICTIONARIES 



ceq1 = """Which one is not a reserve keyword in C Language?
A.auto
B.main
C.case
D.register"""

ceq2 = """A C variable name can start with a __
A.Number
B.Plus Sign (+)
C.Underscore
D.Asterisk (*)"""

ceq3 = """Prototype of a function means ___
A.Name of Function
B.Output of Function
C.Declaration of Function
D.Input of a Function"""

ceq4 = """Which operators perform operations on data in binary level?
[A] Logical operator
[B] Bitwise operator
[C] Additional operators
[D] None of the above"""

ceq5 = """The operator "&" is used for
[A] Bitwise AND
[B] Bitwise OR
[C] Logical AND
[D] Logical OR"""



ceasyquestiondict = {ceq1:'b',ceq2:"c",ceq3:"c",ceq4:"b",ceq5:"a"}



cmq1 = """Which are built-in data structures in C programming?
[A] Arrays
[B] Structures
[C] Files
[D] All of the above"""

cmq2 = """The size of a character variable in C is
[A] 8 bytes
[B] 4 bytes
[C] 2 bytes
[D] 1 byte"""

cmq3 = """The keyword typedef is used to
[A] create a type of function
[B] define the type of function
[C] define the type of a variable
[D] create a new datatype name"""

cmq4 = """By default a real number is treated as a
[A] float
[B] double
[C] long double
[D] integer"""

cmq5 = """Which of the following is not a valid relational operator?
[A] *
[B] ==
[C] >=
[D] <="""



cmediumquestiondict = {cmq1:"d",cmq2:"d",cmq3:"d",cmq4:"a",cmq5:"a"}


chq1 = """What is the return type of ftell function?
[A] double
[B] int
[C] long
[D] float"""

chq2 = """.The && and || operators
[A] compare two numeric values
[B] combine two numeric values short hand operator, &
[C] compare two boolean values
[D] none of these"""

chq3 = """Which is an incorrect variable name?
[A] Id_No
[B] ID_NO
[C] IdNo
[D] Id No"""

chq4 = """Who developed the C programming language
[A] Bjarne Stroustrup
[B] James Gosling
[C] Dennis Ritchies
[D] Ray Boyce"""

chq5 = """A name having a few letters,numbers and special character _(underscore is called)
[A] Keywords
[B] Reserved Keywords
[C] Tokens
[D] Identifiers"""


chardquestiondict = {chq1:"c",chq2:"c",chq3:"d",chq4:"c",chq5:"d"}





# Python Language ALL QUESTIONS . Total 3 DICTIONARIES (UPDATION REQUIRED)


peq1 = """ What is the output for −

S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]

A - 'e'

B - 'i'

C - '90'

D - 'h'"""

peq2 = """What is output of following code −

x = 2
y = 10
x * = y * x + 1
A - 42

B - 41

C - 40

D - 39"""

peq3 = """Select the option for following code −

s = 0
for d in range(0, 5, 0.1):
… s += d
… print(s)
A - Syntax Error

B - Type Error

C - Runtime Error

D - Both b & c"""

peq4 = """How can we check whether the object is instance of class or not. Let us consider an object O which is instance of class B.

A - B.isinstance(O)

B - O.isinstance(B)

C - isinstance(O,B)

D - isinstance(B,O)"""

peq5 = """ What command is used to insert 6 in a list ‘‘L’’ at 3rd position ?

A - L.insert(2,6)

B - L.insert(3,6)

C - L.add(3,6)

D - L.append(2,6)"""



peasyquestiondict = {peq1:'a',peq2:"a",peq3:"d",peq4:"c",peq5:"a"}



pmq1 = """Which among them is used to create an object?

A - A class

B - A function

C - A method

D - A constructor"""

pmq2 = """Which among them will produce {'a', 'b', 'c'}?

A - Tuple(''abc'')

B - List(''abc'')

C - Set(''abac'')

D - None of the above."""

pmq3 = """ Which code is used to open a file for binary writing?

A - ''w''

B - ''wb''

C - ''r+''

D - ''a''"""

pmq4 = """How you can lift the pen of in turtle?

A - Turtle.lift()

B - Turtle.liftup()

C - Turtle.penup()

D - Turtle.up()"""

pmq5 = """Select the valid option for the following Output −
Its an output screen 
|Hello |
|      |
|      |
A - Canvas.Create_text(text= ''Hello! '')

B - Canvas.Create_text(30 , 40, text= ''Hello! '' ,filled= ''green '')

C - Canvas.Create_text(text= ''Hello! '' ,textcolor= ''Green'')

D - Canvas.Create_text(30 , 40, text= ''Hello!'')"""



pmediumquestiondict = {pmq1:"d",pmq2:"d",pmq3:"b",pmq4:"c",pmq5:"b"}


phq1 = """ What will be the output of the following Python code snippet?

X=”hi”
print(“05d”%X)
a) 00000hi
b) 000hi
c) hi000
d) error"""

phq2 = """ What will be the output of the following Python code snippet?

X=”san-foundry”
print(“%56s”,X)
a) 56 blank spaces before san-foundry
b) 56 blank spaces before san and foundry
c) 56 blank spaces after san-foundry
d) no change"""

phq3 = """ What will be the output of the following Python expression if x=456?

print("%-06d"%x)
a) 000456
b) 456000
c) 456
d) error"""

phq4 = """What will be the output of the following Python expression if X=345?

print(“%06d”%X)
a) 345000
b) 000345
c) 000000345
d) 345000000"""

phq5 = """Which of the following formatting options can be used in order to add ‘n’ blank spaces after a given string ‘S’?
a) print(“-ns”%S)
b) print(“-ns”%S)
c) print(“%ns”%S)
d) print(“%-ns”%S)"""


phardquestiondict = {phq1:"d",phq2:"a",phq3:"c",phq4:"b",phq5:"d"}



# Java Language ALL QUESTIONS . Total 3 DICTIONARIES (UPDATION REQUIRED)


jeq1 = """ What is the range of data type short in Java?
A. -128 to 127 
B. -32768 to 32767 
C. -2147483648 to 2147483647 
D. None of the mentioned"""

jeq2 = """ What is the range of data type byte in Java?
A. -128 to 127
B. -32768 to 32767
C. -2147483648 to 2147483647
D. None of the mentioned"""

jeq3 = """ An expression involving byte, int, and literal numbers is promoted to which of these?
A. int
B. long
C. byte
D. float"""

jeq4 = """Which of these literals can be contained in a data type float variable?
A. 1.7e-308
B. 3.4e-038
C. 1.7e+308
D. 3.4e-050"""

jeq5 = """Which data type value is returned by all transcendental math functions?
A. int
B. float
C. double
D. long"""



jeasyquestiondict = {jeq1:'b',jeq2:"a",jeq3:"a",jeq4:"b",jeq5:"c"}



jmq1 = """What is the numerical range of a char in Java?
A. -128 to 127
B. 0 to 256
C. 0 to 32767
D. 0 to 65535"""

jmq2 = """Which of these coding types is used for data type characters in Java?
A. ASCII
B. ISO-LATIN-1
C. UNICODE
D. None of the mentioned"""

jmq3 = """Which of these values can a boolean variable contain?
A. True & False
B. 0 & 1
C. Any integer value.
D. Both a & b"""

jmq4 = """ Which of these occupy first 0 to 127 in Unicode character set used for characters in Java?
A. ASCII
B. ISO-LATIN-1
C. None of the mentioned
D. Both a & b"""

jmq5 = """Which one is a valid declaration of a boolean?
A. boolean b1 = 1;
B. boolean b2 = ‘false’;
C. boolean b3 = false;
D. boolean b4 = ‘true’"""



jmediumquestiondict = {jmq1:"d",jmq2:"c",jmq3:"a",jmq4:"d",jmq5:"c"}


jhq1 = """What is the output of this program?
class mainclass {
public static void main(String args[]) 
{
char a = 'A';
a++;
System.out.print((int)a);
} 
}
A. 66
B. 67
C. 65
D. 64"""

jhq2 = """What is the output of this program?
class mainclass {
public static void main(String args[]) 
{
boolean var1 = true;
boolean var2 = false;
if (var1)
System.out.println(var1);
else
System.out.println(var2);
} 
}
A. 0
B. 1
C. true
D. false"""

jhq3 = """ Which of these method can be used to make the main thread to be executed last among all the threads?
A. stop()
B. sleep()
C. join()
D. call()"""

jhq4 = """Which of these method is used to find out that a thread is still running or not?
A. run()
B. Alive()
C. isAlive()
D. checkRun()"""

jhq5 = """ What is the default value of priority variable MIN_PRIORITY AND MAX_PRIORITY?
A. 0 & 256
B. 0 & 1
C. 1 & 10
D. 1 & 256"""


jhardquestiondict = {jhq1:"a",jhq2:"c",jhq3:"b",jhq4:"c",jhq5:"c"}














playername = None



#LOGIN PANEL

def loginAs():

    z = True
    while z == True:
        print("1. Login As ADMIN")
        print("          - ADD Quiz Questions")
        print("")
        print("")
        print("2. Login As PLAYER")
        print("          - PLAY Quiz")
        print("          - See Instruction On How To Play The Game")
        print("          - EXIT")
        print("")
        print("")
        choice = int(input("Enter your choice : "))
        print("")
        p = True

        while (p == True):
            if choice == 1:
                adminID = input("LOGIN ID : ")
                adminPass = input("PASSWORD : ")
                if adminID == "THINKBOT" and adminPass == "THINKBOT123":
                    print("LOGGED IN SUCCESSFULLY")
                    addquestion()


                    #FUNCTION MIGHT BE NEEDED
                    p = False
                    z = False
                else:
                    print("LOGIN ID OR PASSWORD IS INCORRECT.")
                    print("")

            elif choice == 2:
                playerID = input("LOGIN ID : ")
                playerPass = input("PASSWORD : ")
                loginAs.playername = playerID
        
                if playerID != "" :
                    print("LOGGED IN SUCCESSFULLY")
                    playerchoice()


                    #FUNCTION MIGHT BE NEEDED
                    p = False
                    z = False
                else:
                    print("LOGIN ID OR PASSWORD IS EMPTY.")
                    print("")

            else:
                print("INVALID CHOICE")
                print("")
                p = False
            
            



       
    

    
    
    
    
# COUNTER OR SUM
totalscore = 0
def score():
    global totalscore
    totalscore = totalscore + 1
    


    
    
    
    
# PLAY QUIZ
def playquiz():
    
    k = 0
    print("")
    print("1. QUIZ ON C LANGUAGE")
    print("2. QUIZ ON PYTHON LANGUAGE")
    print("3. QUIZ ON JAVA LANGUAGE")
    print("")
    ch = int(input("Enter your choice : "))
    print("")

    
# FOR C
    if ch == 1:
        print("~~~~~ WELCOME TO C LANGUAGE QUIZ ~~~~~")
        print("")
        print("~~~~~~~~~~~~~~~~~~~~~~~~~ ROUND 1 ~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("")
        
        for q,a in ceasyquestiondict.items():
            k = k+1
            print(f'{k}.{q}')
            print("------------------------------------------------")
            answer = input("Enter your option : ")
            print("------------------------------------------------")
            if answer.lower() == a:
                print("")
                score()
                print("Correct Answer ")
                print(f'CURRENT SCORE : {totalscore}')
                print("")
                
            else:
                print("")
                print("Wrong Answer ")
                print(f'CURRENT SCORE : {totalscore}')
                print("")
                
                
                
        if totalscore >= 3:
            print("")
            print("~~~~~~~~~~~~~~~~~~~~~~~~~ ROUND 2 ~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("")            
            for q,a in cmediumquestiondict.items():
                k = k+1
                print(f'{k}.{q}')
                print("------------------------------------------------")
                answer = input("Enter your option : ")
                print("------------------------------------------------")
                if answer.lower() == a:
                    print("")
                    score()
                    print("Correct Answer ")
                    print(f'CURRENT SCORE : {totalscore}')
                    print("")

                else:
                    print("")
                    print("Wrong Answer ")
                    print(f'CURRENT SCORE : {totalscore}')
                    print("")                
        else:
            print("Your Score is too low to go to the next round")
            print("")
    
    
    
    
    
    
        if totalscore >= 7:
            print("")
            print("~~~~~~~~~~~~~~~~~~~~~~~~~ ROUND 3 ~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("")            
            for q,a in chardquestiondict.items():
                k = k+1
                print(f'{k}.{q}')
                print("------------------------------------------------")
                answer = input("Enter your option : ")
                print("------------------------------------------------")
                if answer.lower() == a:
                    print("")
                    score()
                    print("Correct Answer ")
                    print(f'CURRENT SCORE : {totalscore}')
                    print("")

                else:
                    print("")
                    print("Wrong Answer ")
                    print(f'CURRENT SCORE : {totalscore}')
                    print("")                
        else:
            print("Better Luck Next Time!!! Minimum score required for ROUND 3 is 7 ")
            print(f" {loginAs.playername}'s TOTAL SCORE IS {totalscore}")
    
    

    
# FOR PYTHON

    if ch == 2:
        print("~~~~~ WELCOME TO PYTHON LANGUAGE QUIZ ~~~~~")
        print("")
        print("~~~~~~~~~~~~~~~~~~~~~~~~~ ROUND 1 ~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("")
        
        for q,a in peasyquestiondict.items():
            k = k+1
            print(f'{k}.{q}')
            print("------------------------------------------------")
            answer = input("Enter your option : ")
            print("------------------------------------------------")
            if answer.lower() == a:
                print("")
                score()
                print("Correct Answer ")
                print(f'CURRENT SCORE : {totalscore}')
                print("")
                
            else:
                print("")
                print("Wrong Answer ")
                print(f'CURRENT SCORE : {totalscore}')
                print("")
                
                
                
        if totalscore >= 3:
            print("")
            print("~~~~~~~~~~~~~~~~~~~~~~~~~ ROUND 2 ~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("")            
            for q,a in pmediumquestiondict.items():
                k = k+1
                print(f'{k}.{q}')
                print("------------------------------------------------")
                answer = input("Enter your option : ")
                print("------------------------------------------------")
                if answer.lower() == a:
                    print("")
                    score()
                    print("Correct Answer ")
                    print(f'CURRENT SCORE : {totalscore}')
                    print("")

                else:
                    print("")
                    print("Wrong Answer ")
                    print(f'CURRENT SCORE : {totalscore}')
                    print("")                
        else:
            print("Your Score is too low to go to the next round")
            print("")
    
    
    
    
    
    
        if totalscore >= 7:
            print("")
            print("~~~~~~~~~~~~~~~~~~~~~~~~~ ROUND 3 ~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("")            
            for q,a in phardquestiondict.items():
                k = k+1
                print(f'{k}.{q}')
                print("------------------------------------------------")
                answer = input("Enter your option : ")
                print("------------------------------------------------")
                if answer.lower() == a:
                    print("")
                    score()
                    print("Correct Answer ")
                    print(f'CURRENT SCORE : {totalscore}')
                    print("")

                else:
                    print("")
                    print("Wrong Answer ")
                    print(f'CURRENT SCORE : {totalscore}')
                    print("")                
        else:
            print("Better Luck Next Time!!! Minimum score required for ROUND 3 is 7 ")
            print(f" {loginAs.playername}'s TOTAL SCORE IS {totalscore}")
    
    

# FOR JAVA

    if ch == 3:
        print("~~~~~ WELCOME TO JAVA LANGUAGE QUIZ ~~~~~")
        print("")
        print("~~~~~~~~~~~~~~~~~~~~~~~~~ ROUND 1 ~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("")
        
        for q,a in jeasyquestiondict.items():
            k = k+1
            print(f'{k}.{q}')
            print("------------------------------------------------")
            answer = input("Enter your option : ")
            print("------------------------------------------------")
            if answer.lower() == a:
                print("")
                score()
                print("Correct Answer ")
                print(f'CURRENT SCORE : {totalscore}')
                print("")
                
            else:
                print("")
                print("Wrong Answer ")
                print(f'CURRENT SCORE : {totalscore}')
                print("")
                
                
                
        if totalscore >= 3:
            print("")
            print("~~~~~~~~~~~~~~~~~~~~~~~~~ ROUND 2 ~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("")            
            for q,a in jmediumquestiondict.items():
                k = k+1
                print(f'{k}.{q}')
                print("------------------------------------------------")
                answer = input("Enter your option : ")
                print("------------------------------------------------")
                if answer.lower() == a:
                    print("")
                    score()
                    print("Correct Answer ")
                    print(f'CURRENT SCORE : {totalscore}')
                    print("")

                else:
                    print("")
                    print("Wrong Answer ")
                    print(f'CURRENT SCORE : {totalscore}')
                    print("")                
        else:
            print("Your Score is too low to go to the next round")
            print("")
    
    
    
    
    
    
        if totalscore >= 7:
            print("")
            print("~~~~~~~~~~~~~~~~~~~~~~~~~ ROUND 3 ~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("")            
            for q,a in jhardquestiondict.items():
                k = k+1
                print(f'{k}.{q}')
                print("------------------------------------------------")
                answer = input("Enter your option : ")
                print("------------------------------------------------")
                if answer.lower() == a:
                    print("")
                    score()
                    print("Correct Answer ")
                    print(f'CURRENT SCORE : {totalscore}')
                    print("")

                else:
                    print("")
                    print("Wrong Answer ")
                    print(f'CURRENT SCORE : {totalscore}')
                    print("")                
        else:
            print("Better Luck Next Time!!! Minimum score required for ROUND 3 is 7 ")
            print(f" {loginAs.playername}'s TOTAL SCORE IS {totalscore}")
    

    
    
    
    
    
    
    
    
    
    

    
    
    
    
#ADD QUESTION ADMIN

def addquestion():
    r = True
    while r == True:
        print("")
        print("IN WHICH LANGUAGE WOULD YOU LIKE TO ADD QUESTION")
        print("")
        print("1. C Language")
        print("2. Python Language")
        print("3. Java Language")
        print("4. Exit")
        print("")
        quechoice = int(input("Select Your Option"))
        
        if quechoice == 1:
            print("")
            print("In C Language, in which section you would like to add the question")
            print("")
            print("1. C Language Easy Quiz Questions")
            print("2. C Language Moderate Quiz Questions")
            print("3. C Language Hard Quiz Questions")
            print("")
            cl = int(input("Enter your choice : "))
            print("")
            
            if cl == 1:
                cel = True
                while cel == True:
                    print("")
                    print("Add Question")
                    print("")
                    print("""Example : This Game Is Designed In Which Language? 
                    [A] Java     
                    [B] Python    
                    [C] C   
                    [D] R """)
                    print("")
                    question1 = input("TYPE YOUR QUESTION (Along with 4 options) : ")
                    print("")
                    queanswer = input("ENTER THE CORRECT OPTION : ")
                    
                    ceasyquestiondict[question1] = queanswer
                    
                    print("")
                    print("WOULD YOU LIKE TO ADD FEW MORE QUESTIONS? 1. YES     2. NO ")
                    print("")
                    answ = int(input("ENTER YOUR CHOICE : "))
                    if answ == 1:
                        cel = True
                        print("")
                    else:
                        cel = False

            elif cl == 2:
                cel = True
                while cel == True:
                    print("")
                    print("Add Question")
                    print("")
                    print("""Example : This Game Is Designed In Which Language? 
                    [A] Java     
                    [B] Python    
                    [C] C   
                    [D] R """)
                    print("")
                    question1 = input("TYPE YOUR QUESTION (Along with 4 options) : ")
                    print("")
                    queanswer = input("ENTER THE CORRECT OPTION : ")
                    
                    cmediumquestiondict[question1] = queanswer
                    
                    print("")
                    print("WOULD YOU LIKE TO ADD FEW MORE QUESTIONS? 1. YES     2. NO ")
                    print("")
                    answ = int(input("ENTER YOUR CHOICE : "))
                    if answ == 1:
                        cel = True
                        print("")
                    else:
                        cel = False


                        
            elif cl == 3:
                cel = True
                while cel == True:
                    print("")
                    print("Add Question")
                    print("")
                    print("""Example : This Game Is Designed In Which Language?
                    [A] Java     
                    [B] Python    
                    [C] C   
                    [D] R """)
                    print("")
                    question1 = input("TYPE YOUR QUESTION (Along with 4 options) :")
                    print("")
                    queanswer = input("ENTER THE CORRECT OPTION : ")
                    
                    chardquestiondict[question1] = queanswer
                    
                    print("")
                    print("WOULD YOU LIKE TO ADD FEW MORE QUESTIONS? 1. YES     2. NO ")
                    print("")
                    answ = int(input("ENTER YOUR CHOICE : "))
                    if answ == 1:
                        cel = True
                        print("")
                    else:
                        cel = False
                        
            else: 
                print("INVALID OPTION ")


                        

                        
                        
#PYTHON


        if quechoice == 2:
            print("")
            print("In PYTHON Language, in which section you would like to add the question")
            print("")
            print("1. PYTHON Language Easy Quiz Questions")
            print("2. PYTHON Language Moderate Quiz Questions")
            print("3. PYTHON Language Hard Quiz Questions")
            print("")
            cl = int(input("Enter your choice : "))
            print("")
            
            if cl == 1:
                cel = True
                while cel == True:
                    print("")
                    print("Add Question")
                    print("")
                    print("""Example : This Game Is Designed In Which Language? 
                    [A] Java     
                    [B] Python    
                    [C] C   
                    [D] R """)
                    print("")
                    question1 = input("TYPE YOUR QUESTION (Along with 4 options) : ")
                    print("")
                    queanswer = input("ENTER THE CORRECT OPTION : ")
                    
                    peasyquestiondict[question1] = queanswer
                    
                    print("")
                    print("WOULD YOU LIKE TO ADD FEW MORE QUESTIONS? 1. YES     2. NO ")
                    print("")
                    answ = int(input("ENTER YOUR CHOICE : "))
                    if answ == 1:
                        cel = True
                        print("")
                    else:
                        cel = False

            elif cl == 2:
                cel = True
                while cel == True:
                    print("")
                    print("Add Question")
                    print("")
                    print("""Example : This Game Is Designed In Which Language? 
                    [A] Java     
                    [B] Python    
                    [C] C   
                    [D] R """)
                    print("")
                    question1 = input("TYPE YOUR QUESTION (Along with 4 options) : ")
                    print("")
                    queanswer = input("ENTER THE CORRECT OPTION : ")
                    
                    pmediumquestiondict[question1] = queanswer
                    
                    print("")
                    print("WOULD YOU LIKE TO ADD FEW MORE QUESTIONS? 1. YES     2. NO ")
                    print("")
                    answ = int(input("ENTER YOUR CHOICE : "))
                    if answ == 1:
                        cel = True
                        print("")
                    else:
                        cel = False


                        
            elif cl == 3:
                cel = True
                while cel == True:
                    print("")
                    print("Add Question")
                    print("")
                    print("""Example : This Game Is Designed In Which Language?
                    [A] Java     
                    [B] Python    
                    [C] C   
                    [D] R """)
                    print("")
                    question1 = input("TYPE YOUR QUESTION (Along with 4 options) :")
                    print("")
                    queanswer = input("ENTER THE CORRECT OPTION : ")
                    
                    phardquestiondict[question1] = queanswer
                    
                    print("")
                    print("WOULD YOU LIKE TO ADD FEW MORE QUESTIONS? 1. YES     2. NO ")
                    print("")
                    answ = int(input("ENTER YOUR CHOICE : "))
                    if answ == 1:
                        cel = True
                        print("")
                    else:
                        cel = False
                        
            else: 
                print("INVALID OPTION ")





#JAVA


        if quechoice == 3:
            print("")
            print("In JAVA Language, in which section you would like to add the question")
            print("")
            print("1. JAVA Language Easy Quiz Questions")
            print("2. JAVA Language Moderate Quiz Questions")
            print("3. JAVA Language Hard Quiz Questions")
            print("")
            cl = int(input("Enter your choice : "))
            print("")
            
            if cl == 1:
                cel = True
                while cel == True:
                    print("")
                    print("Add Question")
                    print("")
                    print("""Example : This Game Is Designed In Which Language? 
                    [A] Java     
                    [B] Python    
                    [C] C   
                    [D] R """)
                    print("")
                    question1 = input("TYPE YOUR QUESTION (Along with 4 options) : ")
                    print("")
                    queanswer = input("ENTER THE CORRECT OPTION : ")
                    
                    jeasyquestiondict[question1] = queanswer
                    
                    print("")
                    print("WOULD YOU LIKE TO ADD FEW MORE QUESTIONS? 1. YES     2. NO ")
                    print("")
                    answ = int(input("ENTER YOUR CHOICE : "))
                    if answ == 1:
                        cel = True
                        print("")
                    else:
                        cel = False

            elif cl == 2:
                cel = True
                while cel == True:
                    print("")
                    print("Add Question")
                    print("")
                    print("""Example : This Game Is Designed In Which Language? 
                    [A] Java     
                    [B] Python    
                    [C] C   
                    [D] R """)
                    print("")
                    question1 = input("TYPE YOUR QUESTION (Along with 4 options) : ")
                    print("")
                    queanswer = input("ENTER THE CORRECT OPTION : ")
                    
                    jmediumquestiondict[question1] = queanswer
                    
                    print("")
                    print("WOULD YOU LIKE TO ADD FEW MORE QUESTIONS? 1. YES     2. NO ")
                    print("")
                    answ = int(input("ENTER YOUR CHOICE : "))
                    if answ == 1:
                        cel = True
                        print("")
                    else:
                        cel = False


                        
            elif cl == 3:
                cel = True
                while cel == True:
                    print("")
                    print("Add Question")
                    print("")
                    print("""Example : This Game Is Designed In Which Language?
                    [A] Java     
                    [B] Python    
                    [C] C   
                    [D] R """)
                    print("")
                    question1 = input("TYPE YOUR QUESTION (Along with 4 options) :")
                    print("")
                    queanswer = input("ENTER THE CORRECT OPTION : ")
                    
                    jhardquestiondict[question1] = queanswer
                    
                    print("")
                    print("WOULD YOU LIKE TO ADD FEW MORE QUESTIONS? 1. YES     2. NO ")
                    print("")
                    answ = int(input("ENTER YOUR CHOICE : "))
                    if answ == 1:
                        cel = True
                        print("")
                    else:
                        cel = False
                        
            else: 
                print("INVALID OPTION ")



        if quechoice == 4:
            
            r = False
            loginAs()
                
                
                
                
                
                
                
                    
    
    
    

    
    
    
    
    
    
#PLAYER OPTIONS

def playerchoice():
    print("")
    
    print("LOGGED IN AS PLAYER")
    print(" 1. PLAY Quiz")
    print(" 2. See Instruction On How To Play The Game")
    print(" 3. EXIT")
    print("")
    plchoice = int(input("Enter your choice : "))
    if plchoice == 1:
        playquiz()
    elif plchoice == 2:
        seeinstruction()
    else:
        print("Exited From Game")
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
def seeinstruction():
    print("")
    print("")
    print("""WELCOME TO THE QUIZ GAME
    
    Once you successfully logged in as player you will have 3 quizes option
    1. Quiz On C Language
    2. Quiz On Python Language
    3. Quiz on Java Language
    
    Once you select any one of the above , there are 3 rounds in each quiz
    1. Round 1
    2. Round 2
    3. Round 3
    
    Basically each round will tougher then the previous one.
    
    You will receive one point for correct answers.
    There are no negative marking scheme in the game.
    
    To get qualified for round 2 your total score in round 1 should be equal to or greater than 3.
    To get qualified for round 3 your total score in round 2 should be equal to or greater than 7
    
    Each round has 5 different questions
    
    Best of Luck :D""")
    print("")
    press = int(input("Select 1. To Go back"))
    if press == 1:
        playerchoice()
    else:
        print("See You Soon")
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
#GAME STARTS FROM HERE
loginAs()
# Out:
# 1. Login As ADMIN
#           - ADD Quiz Questions
#
#
# 2. Login As PLAYER
#           - PLAY Quiz
#           - See Instruction On How To Play The Game
#           - EXIT
#
#
# Enter your choice : 1
#
# LOGIN ID : THINKBOT
# PASSWORD : THINKBOT123
# LOGGED IN SUCCESSFULLY
#
# IN WHICH LANGUAGE WOULD YOU LIKE TO ADD QUESTION
#
# 1. C Language
# 2. Python Language
# 3. Java Language
# 4. Exit
#
# Select Your Option1
#
# In C Language, in which section you would like to add the question
#
# 1. C Language Easy Quiz Questions
# 2. C Language Moderate Quiz Questions
# 3. C Language Hard Quiz Questions
#
# Enter your choice : 1
#
#
# Add Question
#
# Example : This Game Is Designed In Which Language?
#                     [A] Java
#                     [B] Python
#                     [C] C
#                     [D] R
#
# TYPE YOUR QUESTION (Along with 4 options) : YOUR PASD HAS BEEN CHANGED
#
# ENTER THE CORRECT OPTION : a
#
# WOULD YOU LIKE TO ADD FEW MORE QUESTIONS? 1. YES     2. NO
#
# ...
